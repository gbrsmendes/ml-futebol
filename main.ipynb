# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
pd.set_option("display.width", 1000)
pd.options.display.float_format = "{:,.2f}".format

import os

# %%
folder = r"D:\repositorio-github\ml-futebol\data"
files = [file for file in os.listdir(folder)]
output_file = os.path.join(folder, 'dataset_consolidado_br.xlsx')

writer = pd.ExcelWriter(output_file, engine='xlsxwriter')
for file in files:
    file_path = os.path.join(folder, file)

    sheet_name = os.path.splitext(file)[0].replace('-', '_').replace('.', '_')
    sheet_name = sheet_name[:31] # Limita a 31 caracteres

    if file.endswith("txt"):
        base = pd.read_csv(file_path, sep=';', encoding='latin-1')
    else:
        base = pd.read_csv(file_path)
    
    
    base.to_excel(writer, sheet_name=sheet_name, index=False)
writer.close()
